# %%
import pandas as pd
import json

# %%
from sources import get_source
# Out:
# //anaconda/lib/python2.7/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import utils

# %%
r=get_source(1)

# %%
dat=r.get()
# Out:
# utils.py:38: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   return next(c['Code'] for c in self.data if c['Name']==country)

# %%
r.value_name
# Out:
# 'Mobile-cellular telephone subscriptions'

# %%
s=get_source(3)

# %%
s.value_name
# Out:
# 'Blood Pressure, Normalised'

# %%
sec = s.get()

# %%
scat=utils.join(dat, sec, key='code')

# %%
scat
# Out:
# [{'code': 'BD', 'x': 81.899321162944105, 'y': 119.2},
#  {'code': 'BE', 'x': 115.690785217498, 'y': 121.2},
#  {'code': 'BF', 'x': 80.643033275884903, 'y': 125.1},
#  {'code': 'BG', 'x': 129.27171496494799, 'y': 125.1},
#  {'code': 'BA', 'x': 90.151960214509899, 'y': 128.2},
#  {'code': 'BB', 'x': 116.456682505339, 'y': 124.7},
#  {'code': 'BM', 'x': 57.946262466070898},
#  {'code': 'BN', 'x': 108.13111525438801, 'y': 118.8},
#  {'code': 'BO', 'x': 92.183851599189495, 'y': 120.0},
#  {'code': 'JP', 'x': 126.54219665740101, 'y': 116.8},
#  {'code': 'BI', 'x': 46.220957198251398, 'y': 128.9},
#  {'code': 'BJ', 'x': 85.644322685983596, 'y': 125.5},
#  {'code': 'BT', 'x': 87.029097404763405, 'y': 126.2},
#  {'code': 'JM', 'x': 111.514582998611, 'y': 123.4},
#  {'code': 'JO', 'x': 179.43301221364499, 'y': 119.1},
#  {'code': 'WS', 'x': 62.370360403254203, 'y': 125.2},
#  {'code': 'BR', 'x': 126.59226452134899, 'y': 124.3},
#  {'code': 'BS', 'x': 80.293072617914106, 'y': 121.0},
# ...

# %%
sorted(scat, key=lambda x: x.get('x'))
# Out:
# [{'code': 'PW', 'y': 130.6},
#  {'code': 'NR', 'y': 122.0},
#  {'code': 'NU', 'y': 125.9},
#  {'code': 'CK', 'y': 125.1},
#  {'code': 'CD', 'y': 126.9},
#  {'code': 'ST', 'y': 131.4},
#  {'code': 'DO', 'y': 122.2},
#  {'code': 'ER', 'x': 7.0499525501088396, 'y': 121.6},
#  {'code': 'KP', 'x': 12.879976192715599, 'y': 122.6},
#  {'code': 'FM', 'x': 21.544131725062201, 'y': 124.9},
#  {'code': 'CF', 'x': 25.868681817216501, 'y': 129.4},
#  {'code': 'MH', 'x': 29.2491461136377, 'y': 120.4},
#  {'code': 'CU', 'x': 29.650727549815802, 'y': 117.6},
#  {'code': 'SH', 'x': 30.722599418040701},
#  {'code': 'DJ', 'x': 34.941055378821702, 'y': 126.7},
#  {'code': 'MW', 'x': 37.938797776954203, 'y': 132.5},
#  {'code': 'KI', 'x': 38.842309696366797, 'y': 122.4},
#  {'code': 'TD', 'x': 40.173068124397098, 'y': 121.0},
#  {'code': 'TV', 'x': 40.338846308995599, 'y': 126.6},
#  {'code': 'ET', 'x': 42.764028805452298, 'y': 127.2},
#  {'code': 'MG', 'x': 44.124583924583, 'y': 129.5},
# ...

# %%
s.value_name
# Out:
# 'Blood Pressure, Normalised'
